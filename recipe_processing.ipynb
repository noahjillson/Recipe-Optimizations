# %%
import pandas as pd

# %%
recipes = pd.read_json("recipes_raw_nosource_fn.json").dropna(axis=1)

# %%
recipes.sort_values(by=['ingredients'], axis=1, ascending=False, key=lambda x: [len(y) for y in x])
# Out:
#                                 VyOSR27DV9/2XWc04AaULLRHh4go0C.  \
# instructions  Special equipment: a deep fryer and an immersi...
# ingredients   [Canola oil, for frying, 1/2 cup olive oil, 2 ...
# title         Eggplant Lasagna with Marinated Red Pepper and...
# picture_link                    tIhYGO0phImk4j45l0ZbfXGaGPWrWGO
#
#                                 39v09iqRtZlSrp6sB93u7RM2RORZOUa  \
# instructions  Position oven rack in lowest position. Heat ov...
# ingredients   [3 cups all-purpose flour, 1 envelope fast-ris...
# title                                           Pizza Four Ways
# picture_link                    9lZ5lTTfMlMkfQ2dLLT07nXqZN7hfSu
#
#                                 Frrt2RtRcM57o9gqs5vQA/WnOsZaSiK  \
# instructions  For the dough: Combine the flour, salt, and su...
# ingredients   [2 1/4 cups unbleached all-purpose flour, 1 1/...
# title         Beef and Goat Cheese Empanada with Piquillo Pe...
# ...

# %%
i = 0
recipes_lst = []
rdict = {}
for key in recipes.keys():
    if i > 100:
        break
    i+=1
    recipes_lst.append(recipes[key])
    rdict[key] = recipes[key]

# %%
df = pd.concat(recipes_lst)

# %%
df.to_json('top100.json', orient='records')

# %%
# Out:
# /var/folders/j8/1bvzgm4101s7j3gvky9rf0mr0000gn/T/ipykernel_30279/3006201197.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df[1]
# ['2 pounds skirt steak, cut into 1/2-inch dice',
#  'Kosher salt and fresh cracked black pepper',
#  '4 to 6 slices thick-cut applewood smoked bacon, 1/4-inch diced (about 1 cup)',
#  '1 1/2 cups 1/4-inch diced red onion',
#  '1/2 cup seeded and finely diced jalapenos (2 medium)',
#  '3 tablespoons minced garlic',
#  '1 teaspoon kosher salt',
#  '2 teaspoons fresh cracked black pepper',
#  'Apple cider vinegar, best quality',
#  '1 (15-ounce) can cannellini beans, with liquid',
#  '1 (15-ounce) can lima beans, with liquid',
#  '1 (15-ounce) can kidney beans, with liquid',
#  '1/3 cup molasses',
#  '2 tablespoons dark brown sugar',
#  '3 tablespoons soy sauce',
# ...
